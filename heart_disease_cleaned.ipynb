# %%
#importing our dependencies
import pandas as pd

# %%
#loading in our csv file with the data
df = pd.read_csv('Resources/heart_disease.csv')
df.head()
# Out:
#    Gender  age      education  currentSmoker  cigsPerDay  BPMeds  \
# 0    Male   39   postgraduate              0         0.0     0.0
# 1  Female   46  primaryschool              0         0.0     0.0
# 2    Male   48     uneducated              1        20.0     0.0
# 3  Female   61       graduate              1        30.0     0.0
# 4  Female   46       graduate              1        23.0     0.0
#
#   prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0              no             0         0    195.0  106.0   70.0  26.97
# 1              no             0         0    250.0  121.0   81.0  28.73
# 2              no             0         0    245.0  127.5   80.0  25.34
# 3              no             1         0    225.0  150.0   95.0  28.58
# 4              no             0         0    285.0  130.0   84.0  23.10
#
#    heartRate  glucose Heart_ stroke
# 0       80.0     77.0            No
# 1       95.0     76.0            No
# ...

# %%
#checking the name of the columns
df.columns
# Out:
# Index(['Gender', 'age', 'education', 'currentSmoker', 'cigsPerDay', 'BPMeds',
#        'prevalentStroke', 'prevalentHyp', 'diabetes', 'totChol', 'sysBP',
#        'diaBP', 'BMI', 'heartRate', 'glucose', 'Heart_ stroke'],
#       dtype='object')

# %%
# Rename the columns using a mapping dictionary
new_column_names = {
    'Gender': 'gender',
    'age': 'age',
    'education': 'education',
    'currentSmoker': 'current_smoker',
    'cigsPerDay': 'cigarettes_per_day',
    'BPMeds': 'bp_meds',
    'prevalentStroke': 'prevalent_stroke',
    'prevalentHyp': 'prevalent_hypertension',
    'diabetes': 'diabetes',
    'totChol': 'total_cholesterol',
    'sysBP': 'systolic_blood_pressure',
    'diaBP': 'diastolic_blood_pressure',
    'BMI': 'bmi',
    'heartRate': 'heart_rate',
    'glucose': 'glucose',
    'Heart_ stroke': 'heart_stroke'
}

df.rename(columns=new_column_names, inplace=True)

df.head()
# Out:
#    gender  age      education  current_smoker  cigarettes_per_day  bp_meds  \
# 0    Male   39   postgraduate               0                 0.0      0.0
# 1  Female   46  primaryschool               0                 0.0      0.0
# 2    Male   48     uneducated               1                20.0      0.0
# 3  Female   61       graduate               1                30.0      0.0
# 4  Female   46       graduate               1                23.0      0.0
#
#   prevalent_stroke  prevalent_hypertension  diabetes  total_cholesterol  \
# 0               no                       0         0              195.0
# 1               no                       0         0              250.0
# 2               no                       0         0              245.0
# 3               no                       1         0              225.0
# 4               no                       0         0              285.0
#
#    systolic_blood_pressure  diastolic_blood_pressure    bmi  heart_rate  \
# ...

# %%
#checking the size of the dataframe
df.shape
# Out:
# (4238, 16)

# %%
#dropping any N/A values in the dataframe
df = df.dropna()

#seeing the amount of rows in the data frame after we drop the N/A's
df.shape
# Out:
# (3656, 16)

# %%
# Save the cleaned DataFrame to a new CSV file
output_file_path = 'Resources/cleaned_data.csv'
df.to_csv(output_file_path, index=False)

print("DataFrame has been saved to:", output_file_path)
# Out:
# DataFrame has been saved to: Resources/cleaned_data.csv

# %%
df.dtypes
# Out:
# gender                       object
# age                           int64
# education                    object
# current_smoker                int64
# cigarettes_per_day          float64
# bp_meds                     float64
# prevalent_stroke             object
# prevalent_hypertension        int64
# diabetes                      int64
# total_cholesterol           float64
# systolic_blood_pressure     float64
# diastolic_blood_pressure    float64
# bmi                         float64
# heart_rate                  float64
# glucose                     float64
# heart_stroke                 object
# dtype: object
